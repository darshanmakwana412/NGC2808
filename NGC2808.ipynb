# %%
# Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Loading the txt Data
txtData = np.loadtxt('NGC2808.txt', dtype='str')

# Creating a pandas Dataframe from the loaded txt data
data = pd.DataFrame(txtData)
data[data.loc[:, data.columns != 35].columns] = data[data.loc[:, data.columns != 35].columns].apply(pd.to_numeric)

# %%
#Getting info of dtypes for the data
data.info()

#printing first 5 rows of the data
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343134 entries, 0 to 343133
# Data columns (total 37 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       343134 non-null  float64
#  1   1       343134 non-null  float64
#  2   2       343134 non-null  float64
#  3   3       343134 non-null  float64
#  4   4       343134 non-null  float64
#  5   5       343134 non-null  float64
#  6   6       343134 non-null  int64
#  7   7       343134 non-null  int64
#  8   8       343134 non-null  float64
#  9   9       343134 non-null  float64
#  10  10      343134 non-null  float64
#  11  11      343134 non-null  float64
#  12  12      343134 non-null  int64
#  13  13      343134 non-null  int64
#  14  14      343134 non-null  float64
#  15  15      343134 non-null  float64
#  16  16      343134 non-null  float64
#  17  17      343134 non-null  float64
#  18  18      343134 non-null  int64
#  19  19      343134 non-null  int64
# ...

# %%
# Plotting a scatter plot of F275W versus F275W-F336W
plt.ylim(30, 15)
plt.xlim(-5, 5)
sns.set(rc = {'figure.figsize':(15,15)})
sns.scatterplot(data[2]-data[8], data[2], alpha=0.03, marker='.')
plt.show()
# Out:
# C:\Users\darsh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data[2].describe()
# Out:
# count    343134.000000
# mean         -6.828262
# std          53.879152
# min         -99.999900
# 25%         -99.999900
# 50%          23.116900
# 75%          25.683500
# max          29.888900
# Name: 2, dtype: float64
